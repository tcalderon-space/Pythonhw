# %%
import numpy as np
import matplotlib.pyplot as plt

h=6.626E-34
c=3.00E8
k=1.38E-23
T=5770

'''
def planckfunc(L):
    B1=(2*h*c**2)
    B2=((L**5)*(np.exp(h*c/(L*k*T)-1)))
    B=B1/B2
    return b

def rayleigh(L):
    return (2*c*k*T)/(L**4)
'''
L=np.linspace(100, 5000, 8000)

B1=(2*h*c**2)
B2=(((L*1e-9)**5)*(np.exp(h*c/((L*1e-9)*k*T)-1)))
b=B1/B2

rayleigh = (2*c*k*T)/((L*1e-9)**4)

# for list_item in range(len(L)):
#     if rayleigh[list_item] > b[list_item] * 1.1:
#         print(L[list_item])

plt.figure(figsize=(10,7))
plt.plot(L, b, label="Planck function", color='purple')
plt.plot(L, rayleigh, label="Rayleigh-Jeans law", color='darkblue', linestyle='dashed')
plt.ylim(0, 10e13)
plt.legend()
plt.xlabel("Wavelength")
plt.ylabel("Planck function/Rayleigh-Jeans law")
#ax.set_xlim(left=3000, right=0)
plt.grid()
plt.show()

# entrydiff = 0
# for entry in range(0, len(b)):
#     entrydiff = b[entry]*2
#     print("does it work?")
#     if entrydiff = rayleigh:
#         diff=entrydiff
#         print(diff)
#     else:
#         print(lol)
